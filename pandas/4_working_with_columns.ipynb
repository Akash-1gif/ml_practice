# %% [markdown]
# # Working with the columns of the DataFrame:

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('tips.csv')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %% [markdown]
# ## Fetching columns:

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size',
#        'price_per_person', 'Payer Name', 'CC Number', 'Payment ID'],
#       dtype='object')

# %% [markdown]
# ## Fetching the data of a single column across all the indices:

# %%
df['total_bill']
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64

# %%
type(df['total_bill'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# ## Grabbing multiple columns:

# %%
cols=['total_bill','tip']
df[cols]
# Out:
#      total_bill   tip
# 0         16.99  1.01
# 1         10.34  1.66
# 2         21.01  3.50
# 3         23.68  3.31
# 4         24.59  3.61
# ..          ...   ...
# 239       29.03  5.92
# 240       27.18  2.00
# 241       22.67  2.00
# 242       17.82  1.75
# 243       18.78  3.00
#
# [244 rows x 2 columns]

# %%
df[['total_bill','tip']]
# Out:
#      total_bill   tip
# 0         16.99  1.01
# 1         10.34  1.66
# 2         21.01  3.50
# 3         23.68  3.31
# 4         24.59  3.61
# ..          ...   ...
# 239       29.03  5.92
# 240       27.18  2.00
# 241       22.67  2.00
# 242       17.82  1.75
# 243       18.78  3.00
#
# [244 rows x 2 columns]

# %% [markdown]
# ## Performing operations on columns:

# %%
df['total_bill']+df['tip']
# Out:
# 0      18.00
# 1      12.00
# 2      24.51
# 3      26.99
# 4      28.20
#        ...
# 239    34.95
# 240    29.18
# 241    24.67
# 242    19.57
# 243    21.78
# Length: 244, dtype: float64

# %%
100*(df['tip']/df['total_bill'])
# Out:
# 0       5.944673
# 1      16.054159
# 2      16.658734
# 3      13.978041
# 4      14.680765
#          ...
# 239    20.392697
# 240     7.358352
# 241     8.822232
# 242     9.820426
# 243    15.974441
# Length: 244, dtype: float64

# %% [markdown]
# ## Creating a new column:

# %%
df['tip_percentage']=100*(df['tip']/(df['total_bill']+df['tip']))

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID  tip_percentage
# ...

# %% [markdown]
# ### rounding off the column values:

# %%
df['price_per_person']=np.round((df['total_bill']+df['tip'])/df['size'],2)    #column values overwritten

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              9.00
# 1         10.34  1.66    Male     No   Sun  Dinner     3              4.00
# 2         21.01  3.50    Male     No   Sun  Dinner     3              8.17
# 3         23.68  3.31    Male     No   Sun  Dinner     2             13.50
# 4         24.59  3.61  Female     No   Sun  Dinner     4              7.05
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3             11.65
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             14.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             12.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              9.78
# 243       18.78  3.00  Female     No  Thur  Dinner     2             10.89
#
#              Payer Name         CC Number Payment ID  tip_percentage
# ...

# %% [markdown]
# ## Removing a column:

# %%
df=df.drop('tip_percentage',axis=1)
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              9.00
# 1         10.34  1.66    Male     No   Sun  Dinner     3              4.00
# 2         21.01  3.50    Male     No   Sun  Dinner     3              8.17
# 3         23.68  3.31    Male     No   Sun  Dinner     2             13.50
# 4         24.59  3.61  Female     No   Sun  Dinner     4              7.05
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3             11.65
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             14.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             12.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              9.78
# 243       18.78  3.00  Female     No  Thur  Dinner     2             10.89
#
#              Payer Name         CC Number Payment ID
# ...
