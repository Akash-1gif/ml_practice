# %% [markdown]
# # Titanic Survival Rate Prediction:

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Importing data:

# %%
df=pd.read_csv('titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### Preparing data:

# %%
df['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
df['Pclass'].isnull().sum()
# Out:
# 0

# %%
df['Sex'].isnull().sum()
# Out:
# 0

# %%
df['Age'].isnull().sum()
# Out:
# 177

# %%
df['Fare'].isnull().sum()
# Out:
# 0

# %%
df_dead=df[df['Survived']==0]
df_dead
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 6              7         0       1                   McCarthy, Mr. Timothy J
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
df_dead_male=df_dead[df_dead['Sex']=="male"]
df_dead_male
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 881          882         0       3              Markun, Mr. Johann  male
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df_dead_male['Age']=df_dead_male['Age'].fillna(df_dead_male['Age'].mean())
df_dead_male
# Out:
# C:\Users\MYPC\AppData\Local\Temp\ipykernel_8324\4233382621.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_dead_male['Age']=df_dead_male['Age'].fillna(df_dead_male['Age'].mean())
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# ...

# %%
df_dead_male['Age'].isnull().sum()
# Out:
# 0

# %%
df_dead_female=df_dead[df_dead['Sex']=="female"]
df_dead_female
# Out:
#      PassengerId  Survived  Pclass  \
# 14            15         0       3
# 18            19         0       3
# 24            25         0       3
# 38            39         0       3
# 40            41         0       3
# ..           ...       ...     ...
# 854          855         0       2
# 863          864         0       3
# 882          883         0       3
# 885          886         0       3
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 14                Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# 24                       Palsson, Miss. Torborg Danira  female   8.0      3
# 38                  Vander Planke, Miss. Augusta Maria  female  18.0      2
# 40      Ahlin, Mrs. Johan (Johanna Persdotter Larsson)  female  40.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df_dead_female['Age']=df_dead_female['Age'].fillna(df_dead_female['Age'].mean())
df_dead_female
# Out:
# C:\Users\MYPC\AppData\Local\Temp\ipykernel_8324\116085491.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_dead_female['Age']=df_dead_female['Age'].fillna(df_dead_female['Age'].mean())
#      PassengerId  Survived  Pclass  \
# 14            15         0       3
# 18            19         0       3
# 24            25         0       3
# 38            39         0       3
# 40            41         0       3
# ..           ...       ...     ...
# 854          855         0       2
# 863          864         0       3
# 882          883         0       3
# 885          886         0       3
# 888          889         0       3
#
#                                                   Name     Sex        Age  \
# ...

# %%
df_dead_female['Age'].isnull().sum()
# Out:
# 0

# %%
df_dead=pd.concat([df_dead_male,df_dead_female],axis=0)
df_dead
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# ..           ...       ...     ...
# 854          855         0       2
# 863          864         0       3
# 882          883         0       3
# 885          886         0       3
# 888          889         0       3
#
#                                               Name     Sex        Age  SibSp  \
# 0                          Braund, Mr. Owen Harris    male  22.000000      1
# 4                         Allen, Mr. William Henry    male  35.000000      0
# 5                                 Moran, Mr. James    male  31.618056      0
# 6                          McCarthy, Mr. Timothy J    male  54.000000      0
# 7                   Palsson, Master. Gosta Leonard    male   2.000000      3
# ...

# %%
df_dead['Age'].isnull().sum()
# Out:
# 0

# %%
df_alive=df[df['Survived']==1]
df_alive
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df_alive_male=df_alive[df_alive['Sex']=='male']
df_alive_male
# Out:
#      PassengerId  Survived  Pclass                             Name   Sex  \
# 17            18         1       2     Williams, Mr. Charles Eugene  male
# 21            22         1       2            Beesley, Mr. Lawrence  male
# 23            24         1       1     Sloper, Mr. William Thompson  male
# 36            37         1       3                 Mamee, Mr. Hanna  male
# 55            56         1       1                Woolner, Mr. Hugh  male
# ..           ...       ...     ...                              ...   ...
# 838          839         1       3                  Chip, Mr. Chang  male
# 839          840         1       1             Marechal, Mr. Pierre  male
# 857          858         1       1           Daly, Mr. Peter Denis   male
# 869          870         1       3  Johnson, Master. Harold Theodor  male
# 889          890         1       1            Behr, Mr. Karl Howell  male
#
#       Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# ...

# %%
df_alive_male['Age']=df_alive_male['Age'].fillna(df_alive_male['Age'].mean())
df_alive_male
# Out:
# C:\Users\MYPC\AppData\Local\Temp\ipykernel_8324\3465767391.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_alive_male['Age']=df_alive_male['Age'].fillna(df_alive_male['Age'].mean())
#      PassengerId  Survived  Pclass                             Name   Sex  \
# 17            18         1       2     Williams, Mr. Charles Eugene  male
# 21            22         1       2            Beesley, Mr. Lawrence  male
# 23            24         1       1     Sloper, Mr. William Thompson  male
# 36            37         1       3                 Mamee, Mr. Hanna  male
# 55            56         1       1                Woolner, Mr. Hugh  male
# ..           ...       ...     ...                              ...   ...
# ...

# %%
df_alive_male['Age'].isnull().sum()
# Out:
# 0

# %%
df_alive_female=df_alive[df_alive['Sex']=="female"]
df_alive_female
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 874          875         1       2
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df_alive_female['Age']=df_alive_female["Age"].fillna(df_alive_female['Age'].mean())
df_alive_female
# Out:
# C:\Users\MYPC\AppData\Local\Temp\ipykernel_8324\658362778.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_alive_female['Age']=df_alive_female["Age"].fillna(df_alive_female['Age'].mean())
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 874          875         1       2
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# ...

# %%
df_alive_female["Age"].isnull().sum()
# Out:
# 0

# %%
df_alive=pd.concat([df_alive_male,df_alive_female],axis=0)
df_alive
# Out:
#      PassengerId  Survived  Pclass  \
# 17            18         1       2
# 21            22         1       2
# 23            24         1       1
# 36            37         1       3
# 55            56         1       1
# ..           ...       ...     ...
# 874          875         1       2
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
#
#                                               Name     Sex        Age  SibSp  \
# 17                    Williams, Mr. Charles Eugene    male  27.276022      0
# 21                           Beesley, Mr. Lawrence    male  34.000000      0
# 23                    Sloper, Mr. William Thompson    male  28.000000      0
# 36                                Mamee, Mr. Hanna    male  27.276022      0
# 55                               Woolner, Mr. Hugh    male  27.276022      0
# ...

# %%
df_alive['Age'].isnull().sum()
# Out:
# 0

# %%
df=pd.concat([df_alive,df_dead],axis=0)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 17            18         1       2
# 21            22         1       2
# 23            24         1       1
# 36            37         1       3
# 55            56         1       1
# ..           ...       ...     ...
# 854          855         0       2
# 863          864         0       3
# 882          883         0       3
# 885          886         0       3
# 888          889         0       3
#
#                                               Name     Sex        Age  SibSp  \
# 17                    Williams, Mr. Charles Eugene    male  27.276022      0
# 21                           Beesley, Mr. Lawrence    male  34.000000      0
# 23                    Sloper, Mr. William Thompson    male  28.000000      0
# 36                                Mamee, Mr. Hanna    male  27.276022      0
# 55                               Woolner, Mr. Hugh    male  27.276022      0
# ...

# %%
df['Age'].isnull().sum()
# Out:
# 0

# %%
target=df['Survived']
target
# Out:
# 17     1
# 21     1
# 23     1
# 36     1
# 55     1
#       ..
# 854    0
# 863    0
# 882    0
# 885    0
# 888    0
# Name: Survived, Length: 891, dtype: int64

# %%
inputs=df.drop(['PassengerId','Name','SibSp','Parch','Ticket','Cabin','Embarked'],axis=1)
inputs
# Out:
#      Survived  Pclass     Sex        Age     Fare
# 17          1       2    male  27.276022  13.0000
# 21          1       2    male  34.000000  13.0000
# 23          1       1    male  28.000000  35.5000
# 36          1       3    male  27.276022   7.2292
# 55          1       1    male  27.276022  35.5000
# ..        ...     ...     ...        ...      ...
# 854         0       2  female  44.000000  26.0000
# 863         0       3  female  25.046875  69.5500
# 882         0       3  female  22.000000  10.5167
# 885         0       3  female  39.000000  29.1250
# 888         0       3  female  25.046875  23.4500
#
# [891 rows x 5 columns]

# %%
le_S=LabelEncoder()

# %%
inputs['Sex_l']=le_S.fit_transform(inputs['Sex'])
inputs
# Out:
#      Survived  Pclass     Sex        Age     Fare  Sex_l
# 17          1       2    male  27.276022  13.0000      1
# 21          1       2    male  34.000000  13.0000      1
# 23          1       1    male  28.000000  35.5000      1
# 36          1       3    male  27.276022   7.2292      1
# 55          1       1    male  27.276022  35.5000      1
# ..        ...     ...     ...        ...      ...    ...
# 854         0       2  female  44.000000  26.0000      0
# 863         0       3  female  25.046875  69.5500      0
# 882         0       3  female  22.000000  10.5167      0
# 885         0       3  female  39.000000  29.1250      0
# 888         0       3  female  25.046875  23.4500      0
#
# [891 rows x 6 columns]

# %%
inputs=inputs.drop(['Sex'],axis=1)
inputs
# Out:
#      Survived  Pclass        Age     Fare  Sex_l
# 17          1       2  27.276022  13.0000      1
# 21          1       2  34.000000  13.0000      1
# 23          1       1  28.000000  35.5000      1
# 36          1       3  27.276022   7.2292      1
# 55          1       1  27.276022  35.5000      1
# ..        ...     ...        ...      ...    ...
# 854         0       2  44.000000  26.0000      0
# 863         0       3  25.046875  69.5500      0
# 882         0       3  22.000000  10.5167      0
# 885         0       3  39.000000  29.1250      0
# 888         0       3  25.046875  23.4500      0
#
# [891 rows x 5 columns]

# %% [markdown]
# ## Training Data:

# %%
model=DecisionTreeClassifier()

# %%
x_train,x_test,y_train,y_test=train_test_split(inputs,target,test_size=0.2,random_state=11)

# %%
x_train
# Out:
#      Survived  Pclass        Age      Fare  Sex_l
# 862         1       1  48.000000   25.9292      0
# 624         0       3  21.000000   16.1000      1
# 86          0       3  16.000000   34.3750      1
# 856         1       1  45.000000  164.8667      0
# 156         1       3  16.000000    7.7333      0
# ..        ...     ...        ...       ...    ...
# 576         1       2  34.000000   13.0000      0
# 874         1       2  28.000000   24.0000      0
# 740         1       1  27.276022   30.0000      1
# 673         1       2  31.000000   13.0000      1
# 696         0       3  44.000000    8.0500      1
#
# [712 rows x 5 columns]

# %%
y_train
# Out:
# 862    1
# 624    0
# 86     0
# 856    1
# 156    1
#       ..
# 576    1
# 874    1
# 740    1
# 673    1
# 696    0
# Name: Survived, Length: 712, dtype: int64

# %%
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
model.score(x_test,y_test)
# Out:
# 1.0
