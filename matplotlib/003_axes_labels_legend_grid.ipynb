# %% [markdown]
# # Axes, Labels, Legend, Grid

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
plt.style.use('dark_background')

# %%
x=[1,2,3,4,5,6,7]
max_t=[50,51,52,48,47,49,46]
min_t=[43,42,40,44,33,35,37]
avg_t=[45,48,48,46,40,42,41]

# %% [markdown]
# ### Creating graphs based on the given data:

# %%
plt.plot(x,max_t)
plt.plot(x,min_t)
plt.plot(x,avg_t)

# %% [markdown]
# ### Labelling the generated graph:

# %%
plt.xlabel('Days')
plt.ylabel('Temperature')
plt.title("Weather")
plt.plot(x,max_t,label='Max Temp')
plt.plot(x,min_t,label='Min Temp')
plt.plot(x,avg_t,label='Avg Temp')
plt.legend()

# %%
plt.xlabel('Days')
plt.ylabel('Temperature')
plt.title("Weather")
plt.plot(x,max_t,label='Max Temp')
plt.plot(x,min_t,label='Min Temp')
plt.plot(x,avg_t,label='Avg Temp')
plt.legend(loc="upper right")

# %%
plt.xlabel('Days')
plt.ylabel('Temperature')
plt.title("Weather")
plt.plot(x,max_t,label='Max Temp')
plt.plot(x,min_t,label='Min Temp')
plt.plot(x,avg_t,label='Avg Temp')
plt.legend(loc="best")

# %% [markdown]
# ## Grid:

# %%
plt.xlabel('Days')
plt.ylabel('Temperature')
plt.title("Weather")
plt.plot(x,max_t,label='Max Temp',color='red',linewidth=3,marker='o',markersize=6,markerfacecolor='orange')
plt.plot(x,min_t,label='Min Temp',color='green',linewidth=3,marker='o',markersize=6,markerfacecolor='orange')
plt.plot(x,avg_t,label='Avg Temp',color='blue',linewidth=3,marker='o',markersize=6,markerfacecolor='orange')
plt.savefig("images/plotgraph.jpg",bbox_inches="tight",pad_inches=2)
plt.legend(loc="best")
plt.grid()

# %% [markdown]
# ## Scattering points:

# %%
x1=np.random.randint(1,101,20)
x1=list(x1)
x1
# Out:
# [43, 67, 68, 32, 55, 63, 73, 51, 83, 22, 3, 29, 91, 67, 23, 94, 44, 59, 90, 62]

# %%
y1=np.random.randint(1,101,20)
y1=list(y1)
y1
# Out:
# [81, 14, 55, 44, 36, 76, 98, 85, 11, 82, 68, 42, 40, 27, 87, 23, 20, 39, 6, 2]

# %%
x2=np.random.randint(1,101,20)
x2=list(x2)
x2
# Out:
# [4, 17, 77, 31, 25, 14, 75, 37, 37, 29, 57, 97, 81, 7, 9, 7, 15, 84, 83, 23]

# %%
y2=np.random.randint(1,101,20)
y2=list(y2)
y2
# Out:
# [36,
#  96,
#  35,
#  21,
#  27,
#  37,
#  63,
#  37,
#  26,
#  99,
#  13,
#  66,
#  69,
#  20,
#  67,
#  57,
#  49,
#  25,
#  76,
#  93]

# %%
plt.scatter(x1,y1,color='red',marker='o',label="Points A")
plt.scatter(x2,y2,color='yellow',marker='o',label="Points B")
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.savefig("images/scatterchart.jpg",bbox_inches="tight",pad_inches=2)
plt.grid()
