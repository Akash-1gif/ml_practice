# %% [markdown]
# # Format Specifiers in Matplotlib:

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('dark_background')

# %%
x=[1,2,3,4,5,6,7]
y=[23,25,26,29,27,28,30]
p=[22,23,25,24,22,23,24]

# %%
plt.plot(x,y)

# %%
plt.plot(x,y,'rD--',x,p,'g+--')
