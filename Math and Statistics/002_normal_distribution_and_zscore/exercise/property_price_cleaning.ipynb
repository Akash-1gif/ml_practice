# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv('bhp.csv')
df
# Out:
#                        location       size  total_sqft  bath   price  bhk  \
# 0      Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1              Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2                   Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3            Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                      Kothanur      2 BHK      1200.0   2.0   51.00    2
# ...                         ...        ...         ...   ...     ...  ...
# 13195                Whitefield  5 Bedroom      3453.0   4.0  231.00    5
# 13196                     other      4 BHK      3600.0   5.0  400.00    4
# 13197     Raja Rajeshwari Nagar      2 BHK      1141.0   2.0   60.00    2
# 13198           Padmanabhanagar      4 BHK      4689.0   4.0  488.00    4
# 13199              Doddathoguru      1 BHK       550.0   1.0   17.00    1
#
#        price_per_sqft
# 0                3699
# 1                4615
# ...

# %%
df1=df.copy()
df1
# Out:
#                        location       size  total_sqft  bath   price  bhk  \
# 0      Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1              Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2                   Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3            Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                      Kothanur      2 BHK      1200.0   2.0   51.00    2
# ...                         ...        ...         ...   ...     ...  ...
# 13195                Whitefield  5 Bedroom      3453.0   4.0  231.00    5
# 13196                     other      4 BHK      3600.0   5.0  400.00    4
# 13197     Raja Rajeshwari Nagar      2 BHK      1141.0   2.0   60.00    2
# 13198           Padmanabhanagar      4 BHK      4689.0   4.0  488.00    4
# 13199              Doddathoguru      1 BHK       550.0   1.0   17.00    1
#
#        price_per_sqft
# 0                3699
# 1                4615
# ...

# %% [markdown]
# ## Setting up limits between 99.9 and 0.1 quantile:

# %%
l1=df1['price_per_sqft'].quantile(0.001)
l1
# Out:
# 1366.184

# %%
l2=df1['price_per_sqft'].quantile(0.999)
l2
# Out:
# 50959.36200000098

# %%
df1=df1[(df1['price_per_sqft']<=l2)&(df1['price_per_sqft']>=l1)]
df1
# Out:
#                        location       size  total_sqft  bath   price  bhk  \
# 0      Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1              Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2                   Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3            Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                      Kothanur      2 BHK      1200.0   2.0   51.00    2
# ...                         ...        ...         ...   ...     ...  ...
# 13195                Whitefield  5 Bedroom      3453.0   4.0  231.00    5
# 13196                     other      4 BHK      3600.0   5.0  400.00    4
# 13197     Raja Rajeshwari Nagar      2 BHK      1141.0   2.0   60.00    2
# 13198           Padmanabhanagar      4 BHK      4689.0   4.0  488.00    4
# 13199              Doddathoguru      1 BHK       550.0   1.0   17.00    1
#
#        price_per_sqft
# 0                3699
# 1                4615
# ...

# %%
df2=df1.copy()
df2
# Out:
#                        location       size  total_sqft  bath   price  bhk  \
# 0      Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1              Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2                   Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3            Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                      Kothanur      2 BHK      1200.0   2.0   51.00    2
# ...                         ...        ...         ...   ...     ...  ...
# 13195                Whitefield  5 Bedroom      3453.0   4.0  231.00    5
# 13196                     other      4 BHK      3600.0   5.0  400.00    4
# 13197     Raja Rajeshwari Nagar      2 BHK      1141.0   2.0   60.00    2
# 13198           Padmanabhanagar      4 BHK      4689.0   4.0  488.00    4
# 13199              Doddathoguru      1 BHK       550.0   1.0   17.00    1
#
#        price_per_sqft
# 0                3699
# 1                4615
# ...

# %%
sns.histplot(df1['price_per_sqft'],kde=True)
# Out:
# <AxesSubplot:xlabel='price_per_sqft', ylabel='Count'>

# %%
mean_x=df1['price_per_sqft'].mean()
mean_x
# Out:
# 6663.6537351958705

# %%
std_x=df1['price_per_sqft'].std()
std_x
# Out:
# 4141.020700174605

# %%
l1=mean_x+(std_x*3)
l1
# Out:
# 19086.715835719682

# %%
l2=mean_x-(std_x*3)
l2
# Out:
# -5759.408365327943

# %%
df2=df2[(df2['price_per_sqft']>=l2)&(df2['price_per_sqft']<=l1)]
df2.head()
# Out:
#                    location       size  total_sqft  bath   price  bhk  \
# 0  Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1          Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2               Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3        Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                  Kothanur      2 BHK      1200.0   2.0   51.00    2
#
#    price_per_sqft
# 0            3699
# 1            4615
# 2            4305
# 3            6245
# 4            4250

# %%
df2.describe()
# Out:
#          total_sqft          bath         price           bhk  price_per_sqft
# count  12874.000000  12874.000000  12874.000000  12874.000000    12874.000000
# mean    1521.279490      2.641603    101.321038      2.751748     6257.158614
# std      928.260107      1.241216    103.508608      1.183229     3086.136007
# min      250.000000      1.000000      8.000000      1.000000     1379.000000
# 25%     1100.000000      2.000000     49.670000      2.000000     4250.000000
# 50%     1272.250000      2.000000     70.000000      3.000000     5368.500000
# 75%     1655.000000      3.000000    115.000000      3.000000     7096.000000
# max    30400.000000     27.000000   2200.000000     27.000000    19061.000000

# %% [markdown]
# ## Calculating z-score for each row on the basis of price_per_sqft:

# %%
df3=df1.copy()
df3.describe()
# Out:
#          total_sqft          bath         price           bhk  price_per_sqft
# count  13172.000000  13172.000000  13172.000000  13172.000000    13172.000000
# mean    1537.861049      2.690100    111.591865      2.799651     6663.653735
# std      967.123711      1.337026    145.372047      1.291130     4141.020700
# min      250.000000      1.000000      8.000000      1.000000     1379.000000
# 25%     1100.000000      2.000000     50.000000      2.000000     4271.000000
# 50%     1274.500000      2.000000     71.550000      3.000000     5438.000000
# 75%     1670.000000      3.000000    120.000000      3.000000     7311.000000
# max    30400.000000     40.000000   3600.000000     43.000000    50349.000000

# %%
df3['z-score']=(df3['price_per_sqft']-mean_x)/std_x
df3.sample(10)
# Out:
#                           location       size  total_sqft  bath  price  bhk  \
# 11214                   R.T. Nagar  9 Bedroom      3600.0   8.0  165.0    9
# 2135                     Gottigere  8 Bedroom      1200.0   8.0   90.0    8
# 3209                      KR Puram  4 Bedroom      1000.0   4.0   75.0    4
# 7507                CV Raman Nagar  4 Bedroom      1100.0   4.0  220.0    4
# 905                          other      1 BHK      1300.0   1.0  200.0    1
# 7734   Bommasandra Industrial Area  2 Bedroom      1200.0   3.0   45.0    2
# 11260                        other      3 BHK      1449.0   3.0   72.0    3
# 274                          other  4 Bedroom      4111.0   4.0  250.0    4
# 547                      Yelahanka      2 BHK      1350.0   2.0   54.0    2
# 11434                   Whitefield  4 Bedroom      4800.0   4.0  550.0    4
#
#        price_per_sqft   z-score
# 11214            4583 -0.502449
# 2135             7500  0.201966
# 3209             7500  0.201966
# ...

# %%
df3[(df3['z-score']>=3)|(df3['z-score']<=(-3))]
# Out:
#                  location       size  total_sqft  bath   price  bhk  \
# 9                   other  6 Bedroom      1020.0   6.0   370.0    6
# 45             HSR Layout  8 Bedroom       600.0   9.0   200.0    8
# 69                  other  3 Bedroom       500.0   3.0   100.0    3
# 87           Rajaji Nagar  6 Bedroom       710.0   6.0   160.0    6
# 157    Mahalakshmi Layout  4 Bedroom      3750.0   4.0   760.0    4
# ...                   ...        ...         ...   ...     ...  ...
# 13081               other  6 Bedroom      8000.0   6.0  2800.0    6
# 13094               other  4 Bedroom      1200.0   5.0   325.0    4
# 13127               other  4 Bedroom      1200.0   5.0   325.0    4
# 13185            Hulimavu      1 BHK       500.0   1.0   220.0    1
# 13186               other  4 Bedroom      1200.0   5.0   325.0    4
#
#        price_per_sqft   z-score
# 9               36274  7.150495
# 45              33333  6.440283
# 69              20000  3.220546
# ...

# %%
df3=df3[(df3['z-score']<=3)&(df3['z-score']>=(-3))]
df3.sample(10)
# Out:
#                    location       size  total_sqft  bath   price  bhk  \
# 8677            Hennur Road      2 BHK      1232.0   2.0   83.00    2
# 8587          HAL 2nd Stage      3 BHK      1600.0   3.0  125.00    3
# 9131                  other      2 BHK      1464.0   2.0   56.00    2
# 8475        Electronic City      2 BHK      1355.0   2.0   97.60    2
# 7400         Thigalarapalya      2 BHK      1245.0   2.0  100.00    2
# 2463               Sarjapur      2 BHK       925.0   2.0   25.00    2
# 682            Varthur Road      2 BHK      1083.0   2.0   61.75    2
# 7106  Raja Rajeshwari Nagar      2 BHK      1060.0   2.0   48.00    2
# 7736                  other  4 Bedroom      2400.0   5.0  180.00    4
# 8121        Old Madras Road  4 Bedroom      3900.0   4.0  175.00    4
#
#       price_per_sqft   z-score
# 8677            6737  0.017712
# 8587            7812  0.277310
# 9131            3825 -0.685496
# 8475            7202  0.130003
# 7400            8032  0.330437
# ...

# %%
df2.describe()
# Out:
#          total_sqft          bath         price           bhk  price_per_sqft
# count  12874.000000  12874.000000  12874.000000  12874.000000    12874.000000
# mean    1521.279490      2.641603    101.321038      2.751748     6257.158614
# std      928.260107      1.241216    103.508608      1.183229     3086.136007
# min      250.000000      1.000000      8.000000      1.000000     1379.000000
# 25%     1100.000000      2.000000     49.670000      2.000000     4250.000000
# 50%     1272.250000      2.000000     70.000000      3.000000     5368.500000
# 75%     1655.000000      3.000000    115.000000      3.000000     7096.000000
# max    30400.000000     27.000000   2200.000000     27.000000    19061.000000

# %%
df3.describe()
# Out:
#          total_sqft          bath         price           bhk  price_per_sqft  \
# count  12874.000000  12874.000000  12874.000000  12874.000000    12874.000000
# mean    1521.279490      2.641603    101.321038      2.751748     6257.158614
# std      928.260107      1.241216    103.508608      1.183229     3086.136007
# min      250.000000      1.000000      8.000000      1.000000     1379.000000
# 25%     1100.000000      2.000000     49.670000      2.000000     4250.000000
# 50%     1272.250000      2.000000     70.000000      3.000000     5368.500000
# 75%     1655.000000      3.000000    115.000000      3.000000     7096.000000
# max    30400.000000     27.000000   2200.000000     27.000000    19061.000000
#
#             z-score
# count  12874.000000
# mean      -0.098163
# std        0.745260
# min       -1.276172
# 25%       -0.582864
# 50%       -0.312762
# 75%        0.104406
# max        2.993790

# %% [markdown]
# ## Comparing z-score data elimination and normal distribution elimination:

# %%
sns.histplot(df2['price_per_sqft'],kde=True)
# Out:
# <AxesSubplot:xlabel='price_per_sqft', ylabel='Count'>

# %%
sns.histplot(df3['price_per_sqft'],kde=True)
# Out:
# <AxesSubplot:xlabel='price_per_sqft', ylabel='Count'>
